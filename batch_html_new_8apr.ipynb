# %% [markdown]
# <a href="https://colab.research.google.com/github/dipangshuk20/compfox-private/blob/main/batch_html_new_8apr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-auth in /usr/local/lib/python3.9/dist-packages (2.17.1)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.9/dist-packages (0.1.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.9/dist-packages (2.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: httplib2>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-httplib2) (0.21.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.12)

# %%
def html_convert(file):
    doc = aw.Document(file)
    doc.save("/content/h_output.html")

# %%
def html_cleaning(html_list):
    g=open("/content/cchanged_html.html",'w+')
    for i in html_list:
        if "Aspose" in i:
            i=''
            g.write(i)
        if "<img" in i:
            i=''
            g.write(i)
        else:
            g.write(i)
    print("done html")
    final_str=g.read()
    return final_str

# %%
def html_root(file):
    html_convert(file)
    with open("/content/h_output.html","r", encoding="utf8") as file:
        soup = BeautifulSoup(file, 'html.parser').prettify()
        html_list = soup.split("\n")
    
    html_till_now=html_cleaning(html_list)
    saaf_safai_num()

    gp=open("/content/updated_cleaning.html","r")
    ht_s=gp.read()
    return ht_s

# %%
from google.cloud import storage
# dest_bucket_name='regular_final_html'

def upload_blob_from_memory(dest_bucket_name, contents, destination_blob_name):
    """Uploads a file to the bucket."""

    # The ID of your GCS bucket
    # bucket_name = "your-bucket-name"

    # The contents to upload to the file
    # contents = "these are my contents"

    # The ID of your GCS object
    # destination_blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(dest_bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_string(contents)

    print(
        f"{destination_blob_name} with contents {contents} uploaded to {dest_bucket_name}."
    )

# %%
import os
import glob
from bs4 import BeautifulSoup
import subprocess
import os
from tempfile import NamedTemporaryFile

# %%
## DEFINE BUCKET _DETAILS
# hi
project_id = 'compfox-367313'
in_bucket_name = '4k_final'

# %%
from google.cloud import storage

# Create a `Client` object
storage_client = storage.Client(project=project_id)

# Get a reference to the bucket
#bucket_name = 'en_banc_2014onwards'
in_bucket = storage_client.bucket(in_bucket_name)

# %%
# !pip install aspose-words
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: aspose-words in /usr/local/lib/python3.9/dist-packages (23.3.0)

# %%
import aspose.words as aw
from google.colab import auth
auth.authenticate_user()

# %%
# def html_convert(doc,count):
#     doc = aw.Document(doc)#"ocr_txt_redo.pdf")
#     doc.save("h_output_{}.html".format(count))

# %%
# def html_cleaning(html_list,count):
#     g=open("cchanged_html_{}.html".format(count),'w+')
#     for i in html_list:
#         if "Aspose" in i:
#             i=''
#             g.write(i)
#         if "<img" in i:
#             i=''
#             g.write(i)
#         else:
#             g.write(i)
#     print("done html")

# %%
# def get_html_list(doc):
#   with open(doc,"r") as file:
#     soup = BeautifulSoup(file, 'html.parser').prettify()
#     html_list = soup.split("\n")
#   return html_list

# %%
# def html_root(doc,count):
#     html_convert(doc, count)
#     # with open("h_output.html","r", encoding="utf8") as file:
#     #     soup = BeautifulSoup(file, 'html.parser').prettify()
#     #     html_list = soup.split("\n")
#     html_list=get_html_list(doc)
#     html_cleaning(html_list,count)
#     gp=open("cchanged_html_{}.html".format(count),"r")
#     ht_s=gp.read()
#     ht_p=saaf_safai_num(ht_s)
#     return ht_p

# %%
def jsonify(l):
    import json
    with open('batch_for_html.json', 'a', encoding='utf-8') as f:
        json.dump(l, f, ensure_ascii=False, indent=4)

# %%
from bs4 import BeautifulSoup

def saaf_safai_num():
  ## Removes nuber from code html
  ok=open("/content/cchanged_html.html","r")
  soup=BeautifulSoup(ok.read(), 'html.parser')
  for span in soup.find_all('span'):
    if any(char.isdigit() for char in span.text):
      span.decompose()
  with open('/content/updated_cleaning.html', 'w') as f:
    f.write(soup.prettify())

  return "done"

# %%
# remove_num(test_debug1)

# %%
import re
def remove_num(html_content):
  soup=BeautifulSoup(html_content, 'html.parser')
  for span in soup.find_all('span'):
    if re.match('^[0-9]+$', span.text.strip()):
        span.extract()
  return soup.prettify()

# %%
# remove_num(test_debug1)

# %%
# from bs4 import BeautifulSoup

# def saaf_safai_num(html_content_passed_here):
#   ## Removes nuber from code html
#   soup=BeautifulSoup(html_content_passed_here, 'html.parser')
#   for span in soup.find_all('span'):
#     if any(char.isdigit() for char in span.text):
#       span.decompose()
#   # with open('updated.html', 'w') as f:
#   #   f.write(soup.prettify())

#   return soup.pretiffy()

# %%
#pk
def convert_to_pdf(x):
    name=x.split(".")[0]
    file = open(name+".pdf", 'wb')
    for line in open(x, 'rb').readlines():
        file.write(line)
    file.close()

# %%
import os
def yopgno(): 
  cmd = "pdfinfo /content/ocr_txt_redo.pdf | grep 'Pages' | awk '{print $2}'" 
  return os.popen(cmd).read().strip()

# %%
yopgno()
# Out:
# ''

# %%
from google.cloud import storage
dest_bucket_name = "regular_final_html"
import json
def upload_blob_from_memory(dest_bucket_name, contents, destination_blob_name):
    """Uploads a file to the bucket."""

    # The ID of your GCS bucket
    dest_bucket_name = "regular_final_html"

    # The contents to upload to the file
    # contents = "these are my contents"

    # The ID of your GCS object
    # destination_blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(dest_bucket_name)
    blob = bucket.blob(destination_blob_name)


    blob.upload_from_string(json.dumps(contents))

    print(
        f"{destination_blob_name} with contents {contents} uploaded to {dest_bucket_name}."
    )

# %% [markdown]
# # version 1 with no split

# %%
# #v1
# import os
# #thalaiva 
# new_json=[]
# line_count=1
# done_name=[]
# json_file='new_json_04.json'
# skip_func = False
# for blob in bucket.list_blobs():
#     if blob.name.endswith('.pdf'):
#       if blob.name == '2019_08_12_Macedo, Maricela.pdf':
#         skip_func = False
#       if skip_func!=True:
#         done_name.append(blob.name)
#         print(blob.name)
#         pdf_blob = blob.download_as_string()
#         g=open('ocr_txt_redo.txt', 'wb')
#         g.write(pdf_blob)
#         convert_to_pdf('ocr_txt_redo.txt')
#         html_root()
#         # break
#         h= open('/content/cchanged_html.html','r')
#         saaf_safai_num(remove_num(h.read()))
#         hmm=open('/content/cchanged_html.html','r')
#         html_content_bro=hmm.read()

#         upload_blob_from_memory('regular_final_html',html_content_bro,blob.name)
#         new_json.append({blob.name:html_content_bro})
#         hmm.close()
#         # line_count+=1
#         # file_num=1
#         # s=open(r"/content/drive/MyDrive/html_batch_compfox/json_30.json",'a')
#         # s.write(str(new_json))
#           # new_json=[]



#         # output_dir = '/content/html_test'
#         # html_root()
#         # html_path = convert_pdf_to_html_v2("/content/extract_for_html.pdf", output_dir)
#         # pages=int(yopgno())
#         # merge_output_path="/content/merged_html.html"
#         # soup = BeautifulSoup("<html><body></body></html>", "html.parser")
#         # html_files = glob.glob('/content/drive/MyDrive/html_test/*.html')
#         # for i in range(1,pages):
#         #   gf=open(f"/content/drive/MyDrive/html_test/extract_for_html-{i}.html","r")
#         #   content=gf.read()
#         #   body = BeautifulSoup(content, "html.parser").body

#         #   if body is not None:
#         #     div = body.find('div')
#         #     if div is not None:
#         #       soup.body.append(div)
#         #     else:
#         #       soup.body.append(body_contents = body.contents)
#         # with open(merge_output_path, "w") as f:
#         #     f.write(str(soup))
#         # print("done merging")
#         # clean_html()

# %%
# len(new_json)

# %%
# !pip install PyPDF2

# %% [markdown]
# ```
#  Used pikepdf
# ```
#
#  Code to split pdf

# %%
# !pip install pikepdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.9/dist-packages (7.1.2)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.9/dist-packages (from pikepdf) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from pikepdf) (23.0)
# Requirement already satisfied: Pillow>=9.0 in /usr/local/lib/python3.9/dist-packages (from pikepdf) (9.5.0)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.9/dist-packages (from pikepdf) (4.9.2)

# %%
import os
from pikepdf import Pdf
# a dictionary mapping PDF file to original PDF's page range
file2pages = {
    0: [0, 5], # 1st splitted PDF file will contain the pages from 0 to 9 (9 is not included)
    1: [5, 10], # 2nd splitted PDF file will contain the pages from 9 (9 is included) to 11
    2: [10, 15],
    3:[15,20],
    4:[20,25],
    5:[25,30],# 3rd splitted PDF file will contain the pages from 11 until the end or until the 100th page (if exists)
}

def split_pdf_samunder(pdf_name):
# the target PDF document to split
# filename = "diagnostics-12-00915-v2 (3).pdf"
# make the new splitted PDF files
# load the PDF file
  pdf = Pdf.open(pdf_name)
  new_pdf_files = [ pdf.new() for i in file2pages ]
# the current pdf file index
  new_pdf_index = 0
# iterate over all PDF pages
  for n, page in enumerate(pdf.pages):
      if n in list(range(*file2pages[new_pdf_index])):
        new_pdf_files[new_pdf_index].pages.append(page)
        # print(f"[*] Assigning Page {n} to the file {new_pdf_index}")
      else:
        name, ext = os.path.splitext(pdf_name)
        output_filename = f"{name}-{new_pdf_index}.pdf"
        # save the PDF file
        new_pdf_files[new_pdf_index].save(output_filename)
        # print(f"[+] File: {output_filename} saved.")
        # go to the next file
        new_pdf_index += 1
        # add the `n` page to the `new_pdf_index` file
        new_pdf_files[new_pdf_index].pages.append(page)
        # print(f"[*] Assigning Page {n} to the file {new_pdf_index}")


  name, ext = os.path.splitext(pdf_name)
  output_filename = f"{name}-{new_pdf_index}.pdf"
  new_pdf_files[new_pdf_index].save(output_filename)
  print(f"[+] File: {output_filename} saved.")

  return pdf.pages

# %% [markdown]
# # Version 2: with pdf split added

# %%
# !pip install pikepdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.9/dist-packages (7.1.2)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.9/dist-packages (from pikepdf) (4.9.2)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.9/dist-packages (from pikepdf) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from pikepdf) (23.0)
# Requirement already satisfied: Pillow>=9.0 in /usr/local/lib/python3.9/dist-packages (from pikepdf) (9.5.0)

# %%
import os
from pikepdf import Pdf
# a dictionary mapping PDF file to original PDF's page range
file2pages = {
    0: [0, 5], # 1st splitted PDF file will contain the pages from 0 to 9 (9 is not included)
    1: [5, 10], # 2nd splitted PDF file will contain the pages from 9 (9 is included) to 11
    2: [10, 15],
    3:[15,20],
    4:[20,25],
    5:[25,30],# 3rd splitted PDF file will contain the pages from 11 until the end or until the 100th page (if exists)
}

def split_pdf_samunder(pdf_name):
# the target PDF document to split
# filename = "diagnostics-12-00915-v2 (3).pdf"
# make the new splitted PDF files
# load the PDF file
  pdf = Pdf.open(pdf_name)
  new_pdf_files = [ pdf.new() for i in file2pages ]
# the current pdf file index
  new_pdf_index = 0
# iterate over all PDF pages
  for n, page in enumerate(pdf.pages):
      if n in list(range(*file2pages[new_pdf_index])):
        new_pdf_files[new_pdf_index].pages.append(page)
        # print(f"[*] Assigning Page {n} to the file {new_pdf_index}")
      else:
        name, ext = os.path.splitext(pdf_name)
        output_filename = f"{name}-{new_pdf_index}.pdf"
        # save the PDF file
        new_pdf_files[new_pdf_index].save(output_filename)
        # print(f"[+] File: {output_filename} saved.")
        # go to the next file
        new_pdf_index += 1
        # add the `n` page to the `new_pdf_index` file
        new_pdf_files[new_pdf_index].pages.append(page)
        # print(f"[*] Assigning Page {n} to the file {new_pdf_index}")


  name, ext = os.path.splitext(pdf_name)
  output_filename = f"{name}-{new_pdf_index}.pdf"
  new_pdf_files[new_pdf_index].save(output_filename)
  print(f"[+] File: {output_filename} saved.")

  return len(pdf.pages)

# %%
htmls={}
import json
def get_merge_html(num_of_pdfs):
  for i in range(0,num_of_pdfs):
    htmls[i]=html_root("/content/ocr_txt_redo-{}.pdf".format(i))
    ob=open("obj.json","w")
    ob.write(json.dumps(htmls))
  return htmls

# %%
done_html_v1=['yeah']

# %%
import os
import time
#thalaiva
new_json=[]
line_count=1
done_html_v2=[]
json_file='new_json_27.json'
for blob in in_bucket.list_blobs():
    if blob.name.endswith('.pdf'):
        if blob.name not in done_html_v1:
          done_html_v2.append(blob.name)
          print(blob.name)
          
          pdf_blob = blob.download_as_string()
          g=open('/content/ocr_txt_redo.txt', 'wb')
          g.write(pdf_blob)
          convert_to_pdf('/content/ocr_txt_redo.txt')
          # time.sleep(3)
          num_pages=split_pdf_samunder('/content/ocr_txt_redo.pdf')
          print(num_pages)
          num_of_blocks=int(num_pages/5)+1
          # num_pages_o=yopgno()
          html_content_bro=get_merge_html(num_of_blocks)
          # print(html_content_bro)
          # json_str = json.dumps(html_content_bro)

          # html_root()
          # # break
          # h= open('/content/cchanged_html.html','r')
          # saaf_safai_num(h.read())
          # hmm=open('/content/cchanged_html.html','r')
          # html_content_bro=hmm.read()
          upload_blob_from_memory('compfox-htmls-manual',html_content_bro,blob.name)
          new_json.append({blob.name:html_content_bro})
          
            # new_json=[]
  
  
  
        
        # output_dir = '/content/html_test'
        # html_root()
        # html_path = convert_pdf_to_html_v2("/content/extract_for_html.pdf", output_dir)
        # pages=int(yopgno())
        # merge_output_path="/content/merged_html.html"
        # soup = BeautifulSoup("<html><body></body></html>", "html.parser")
        # html_files = glob.glob('/content/drive/MyDrive/html_test/*.html')
        # for i in range(1,pages):
        #   gf=open(f"/content/drive/MyDrive/html_test/extract_for_html-{i}.html","r")
        #   content=gf.read()
        #   body = BeautifulSoup(content, "html.parser").body

        #   if body is not None:
        #     div = body.find('div')
        #     if div is not None:
        #       soup.body.append(div)
        #     else:
        #       soup.body.append(body_contents = body.contents)
        # with open(merge_output_path, "w") as f:
        #     f.write(str(soup))
        # print("done merging")
        # clean_html()
# Out:
# 2014_02_03_Alarcon, Yonir.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 9
# done html
# done html
# 2014_02_03_Alarcon, Yonir.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:534pt; height:290pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:71.85pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:15.65pt">\n    <span style="height:0pt; margin-top:-71.85pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:123.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     WORKERS\' COMPENSATION\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:12.5pt">\n     BOARD\n    </span>\n   </p>\n   <p style="margin-top:9.55pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.9pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:191.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:13pt">\n     OF\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:8.7pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:8.35pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.65pt">\n    <span style="font-size:12.5pt; letter-spacing:272pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     Case No.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:14.8pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     (SBR\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:14.05pt">\n    <span style="font-size:12.5pt">\n     YONIR\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     ALARCON,\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:122pt; margin-bottom:0pt; text-align:justify; line-height:13.8pt">\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.85pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:324.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-weight:bold">\n     AND\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     DECISION\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:142pt; margin-bottom:0pt; text-align:justify; line-height:14.7pt">\n    <span style="font-size:10pt; font-weight:bold">\n     VS.\n    </span>\n    <span style="letter-spacing:230.6pt; -aw-import:spaces">\n    </span>\n    <span>\n     AFTER\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.1pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:337.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     RECONSIDERATION\n    </span>\n   </p>\n   ...
# 2014_02_03_Boston, Keisha.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 6
# done html
# done html
# 2014_02_03_Boston, Keisha.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:533pt; height:290pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:70.65pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:15.7pt">\n    <span style="height:0pt; margin-top:-70.65pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:123.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:2.05pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="letter-spacing:0.75pt; -aw-import:spaces">\n    </span>\n    <span>\n     APPEALS BOARD\n    </span>\n   </p>\n   <p style="margin-top:8.75pt; margin-left:3pt; margin-bottom:0pt; text-align:justify; line-height:15.45pt">\n    <span style="letter-spacing:192.25pt; -aw-import:spaces">\n    </span>\n    <span>\n     STATE OF CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:11.15pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:287pt; margin-bottom:0pt; text-align:justify; line-height:13.35pt">\n    <span>\n     Case\n    </span>\n    <span style="font-size:11.5pt">\n     No.\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:15.35pt">\n    <span style="letter-spacing:7.25pt; -aw-import:spaces">\n    </span>\n    <span>\n     KEISHA BOSTON,\n    </span>\n    <span style="letter-spacing:201.75pt; -aw-import:spaces">\n    </span>\n    <span>\n     (Los Angeles\n    </span>\n    <span style="font-size:12.5pt">\n     District\n    </span>\n    <span>\n     Office)\n    </span>\n   </p>\n   <p style="margin-top:10.15pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:13.85pt">\n    <span style="font-weight:bold; font-style:italic; letter-spacing:106.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:348pt; margin-bottom:0pt; text-align:justify; line-height:14pt">\n    <span>\n     OPINION\n    </span>\n    <span style="-aw-import:spaces">\n    </span>\n    <span>\n     AND ORDER\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:14.95pt">\n    <span style="font-size:11.5pt; letter-spacing:125.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt">\n     vs.\n    </span>\n    <span style="letter-spacing:174.15pt; -aw-import:spaces">\n    </span>\n    <span>\n     GRANTING\n    </span>\n    <span style="font-size:12.5pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     PETITION\n    </span>\n    <span style="letter-spacing:0.3pt; -aw-import:spaces">\n    </span>\n    <span>\n     FOR\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:352pt; margin-bottom:0pt; text-align:justify; line-height:13.55pt">\n    <span style="font-size:12.5pt">\n     RECONSIDERATION\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.05pt">\n    <span style="letter-spacing:330.8pt; -aw-import:spaces">\n    </span>\n    <span>\n     AND DECISION\n   ...
# 2014_02_03_Cisneros, Uriel.pdf
# [+] File: /content/ocr_txt_redo-2.pdf saved.
# 11
# done html
# done html
# done html
# 2014_02_03_Cisneros, Uriel.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:534pt; height:290pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65540">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:56.55pt 110.25pt 0pt 5pt; text-indent:1pt; line-height:24.95pt">\n    <span style="height:0pt; margin-top:-56.55pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:8pt; font-weight:bold">\n     I\n    </span>\n    <span style="letter-spacing:127.8pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:2.3pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:0.45pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:12.5pt">\n     BOARD\n    </span>\n    <span style="font-weight:bold; letter-spacing:192.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:5.3pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:3.4pt; margin-left:290pt; margin-bottom:0pt; text-align:justify; line-height:13.3pt">\n    <span>\n     Case\n    </span>\n    <span style="font-size:11.5pt">\n     Nos.\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.45pt; -aw-import:spaces">\n    </span>\n   </p>\n   <p style="margin:0.05pt 32.1pt 0pt 5pt; line-height:23pt">\n    <span style="font-size:12.5pt; letter-spacing:7.2pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     URIEL\n    </span>\n    <span style="font-weight:bold; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     CISNEROS,\n    </span>\n    <span style="letter-spacing:210.8pt; -aw-import:spaces">\n    </span>\n    <span>\n     (Los Angeles\n    </span>\n    <span style="font-size:12.5pt">\n     District\n    </span>\n    <span>\n     Office)\n    </span>\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:105.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:350pt; margin-bottom:0pt; text-align:justify; line-height:13.95pt">\n    <span style="font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     AND\n    </span>\n    <span>\n     ORDER\n    </span>\n   </p>\n   <p style="margin-top:0.55pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:15.1pt">\n    <span style="font-size:11pt; font-weight:bold; letter-spacing:126.75pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11pt; font-weight:bold">\n     vs.\n    </span>\n    <span style="font-weight:bold; letter-spacing:174.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     GRANTING PETITION\n    </span>\n    <span>\n     FOR\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:309pt; margin-bottom:0pt; text-align:justify; line-height:13.95pt">\n    <span>\n     RECONSIDERATION\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold; le ...
# 2014_02_03_Dordines, Benedicto.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 6
# done html
# done html
# 2014_02_03_Dordines, Benedicto.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="height:0pt; display:block; position:absolute; z-index:-65537">\n     </span>\n     <span style="-aw-import:ignore">\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:28pt 105.7pt 0pt 20pt; text-indent:2pt; line-height:25.2pt">\n    <span style="height:0pt; margin-top:-28pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:123.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:2.05pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.45pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span>\n     BOARD\n    </span>\n    <span style="font-weight:bold; letter-spacing:193.6pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:10.65pt; margin-left:20pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:8.05pt; margin-left:20pt; margin-bottom:0pt; text-align:justify; line-height:15.7pt">\n    <span style="letter-spacing:272.5pt; -aw-import:spaces">\n    </span>\n    <span>\n     Case\n    </span>\n    <span style="font-size:11.5pt">\n     No.\n    </span>\n   </p>\n   <p style="margin:0pt 20.05pt 0pt 20pt; text-indent:18pt; line-height:12.5pt">\n    <span style="font-weight:bold">\n     BENEDICTO DORDINES,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:166.7pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     (Marina\n    </span>\n    <span style="-aw-import:spaces">\n    </span>\n    <span>\n     del Rey\n    </span>\n    <span style="font-size:12.5pt">\n     District\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:137pt; margin-bottom:0pt; text-align:justify; line-height:13.85pt">\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:20pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:156pt; margin-bottom:0pt; text-align:justify; line-height:14.7pt">\n    <span style="font-size:11.5pt">\n     vs.\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:200.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     DENYING\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:19pt; margin-bottom:0pt; text-align:justify; line-height:15.5pt">\n    <span style="font-weight:bold; letter-spacing:320.75pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     PETITION\n    </span>\n    <span style="font-size:12.5pt">\n     FOR\n    </span>\n    <span>\n     REMOVAL\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:38pt; margin-bottom:0pt; text-align:justify; line-height:14.4pt">\n    <span>\n     WAL-MART\n    </span>\n    <span style="font-weight:bold">\n     ASSOCIATES, INC.;\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:19pt; margin-bottom:0pt; text-align:justify; line-height:14.1pt">\n    <span style="font-weight:bold; let ...
# 2014_02_03_Kilcullen, Donald.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 5
# done html
# done html
# 2014_02_03_Kilcullen, Donald.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:538pt; height:292pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:63pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:15.15pt">\n    <span style="height:0pt; margin-top:-63pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:122.15pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     WORKERS\' COMPENSATION\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:11.5pt">\n     BOARID\n    </span>\n   </p>\n   <p style="margin-top:8.35pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:15.1pt">\n    <span style="font-weight:bold; letter-spacing:187.25pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:12.5pt">\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:10.3pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:295pt; margin-bottom:0pt; text-align:justify; line-height:14.1pt">\n    <span style="font-size:12.5pt">\n     Case No.\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:14.8pt">\n    <span style="font-weight:bold; letter-spacing:6.15pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     DONALD\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     KILCULLEN,\n    </span>\n    <span style="font-size:13pt; letter-spacing:176.15pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     (Santa\n    </span>\n    <span style="font-size:12.5pt">\n     Ana\n    </span>\n    <span style="font-size:13pt">\n     District\n    </span>\n    <span style="font-size:12.5pt">\n     Office)\n    </span>\n   </p>\n   <p style="margin-top:8.35pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:13.85pt">\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:103.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:9.45pt; margin-left:12pt; margin-bottom:0pt; text-align:justify; line-height:15.7pt">\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:124.4pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     vs.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:187.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-weight:bold">\n     AND\n    </span>\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n   </p>\n   <p style="margin-top:0.9pt; margin-left:342pt; margin-bottom:0pt; text-align:justify; line-height:14.05pt">\n    <span style="font-size:12.5pt; font-weight:bold">\n     GRANTING PETITION\n    </span>\n    <span style="font-size:12.5pt">\n     FOR\n    </span>\n   </p>\n   <p style="margin:0.05pt 1.4pt 0pt 12pt; text-align:center; line-height:13pt">\n    < ...
# 2014_02_03_Levenets, Peter.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 9
# done html
# done html
# 2014_02_03_Levenets, Peter.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="height:0pt; display:block; position:absolute; z-index:-65537">\n     </span>\n     <span style="-aw-import:ignore">\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:65.15pt; margin-left:24pt; margin-bottom:0pt; text-align:justify; line-height:13.5pt">\n    <span style="height:0pt; margin-top:-65.15pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:124.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:1.6pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-weight:bold; letter-spacing:1.4pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span>\n     BOARD\n    </span>\n   </p>\n   <p style="margin-top:10.75pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:13.95pt">\n    <span style="font-weight:bold; letter-spacing:192.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:12.5pt">\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:10.95pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:308pt; margin-bottom:0pt; text-align:justify; line-height:13.3pt">\n    <span>\n     Case No.\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.8pt; -aw-import:spaces">\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:14.55pt">\n    <span style="font-size:12.5pt; letter-spacing:7.2pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     PETER\n    </span>\n    <span style="font-weight:bold">\n     LEVENETS,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:200.75pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     (Sacramento\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:0.45pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     District\n    </span>\n    <span>\n     Office)\n    </span>\n   </p>\n   <p style="margin-top:9.85pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:13.85pt">\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:106.65pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:11.25pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:12.55pt">\n    <span style="font-size:11pt; font-weight:bold; letter-spacing:125.75pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11pt; font-weight:bold">\n     vs.\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:380pt; margin-bottom:0pt; text-align:justify; line-height:13.55pt">\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     DENYING\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:13.7pt">\n    <span style="font-weight:bold; letter-spacing:7.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n   ...
# 2014_02_03_McDonald, Tim.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 3
# done html
# 2014_02_03_McDonald, Tim.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="height:0pt; display:block; position:absolute; z-index:-65539">\n     </span>\n     <span style="-aw-import:ignore">\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:34.45pt 113.1pt 0pt 19pt; text-indent:1pt; line-height:25.5pt">\n    <span style="height:0pt; margin-top:-34.45pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:123.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:2.05pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.4pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span>\n     BOARD\n    </span>\n    <span style="font-weight:bold; letter-spacing:192.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.1pt; margin-left:19pt; margin-bottom:8.9pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <div style="-aw-headerfooter-type:footer-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="font-weight:bold; color:#ff0000">\n     </span>\n    </p>\n   </div>\n  </div>\n  <br style="clear:both; mso-break-type:section-break"/>\n  <div>\n   <p style="margin-top:3.15pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:12.5pt">\n   </p>\n   <p style="margin-top:0pt; margin-left:23pt; margin-bottom:0pt; text-align:justify; line-height:13.7pt">\n    <span style="font-size:12.5pt">\n     TIM\n    </span>\n    <span>\n     MCDONALD,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:123pt; margin-bottom:0pt; text-align:justify; line-height:14.3pt">\n    <span style="font-size:13pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.85pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:12.5pt">\n   </p>\n   <p style="margin-top:0pt; margin-left:142pt; margin-bottom:0pt; text-align:justify; line-height:12.45pt">\n    <span style="font-size:11.5pt; font-weight:bold">\n     vs.\n    </span>\n   </p>\n   <p style="margin-top:1.15pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:12.15pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:5pt; margin-bottom:0pt; text-indent:19pt; line-height:12.5pt">\n    <span style="font-size:11.5pt; font-weight:bold">\n     SAN\n    </span>\n    <span style="font-weight:bold">\n     FRANCISCO\n    </span>\n    <span style="font-weight:bold">\n     TIG\n    </span>\n    <span style="font-size:12.5pt">\n     SPECIALTY\n    </span>\n    <span style="font-weight:bold; letter-spacing:7.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     INSURANCE\n    </span>\n    <span>\n     COMPANY,\n    </span>\n    <span style="font-size:12.5pt">\n     Administered\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:0.8pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     by\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:24pt; margin-bottom:0pt; text-align:justify; line-height:14.95pt"> ...
# 2014_02_03_Morash, Glenn.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 3
# done html
# 2014_02_03_Morash, Glenn.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:538pt; height:292pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:60.2pt; margin-left:17pt; margin-bottom:0pt; text-align:justify; line-height:17.5pt">\n    <span style="height:0pt; margin-top:-60.2pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:122.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     WORKERS\'\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     COMPENSATION APPEALS\n    </span>\n    <span style="font-size:13pt">\n     BOARD\n    </span>\n   </p>\n   <p style="margin-top:8.15pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:15.45pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:191.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:12.5pt">\n     OF\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.85pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin:0.05pt 32.2pt 0pt 15pt; text-indent:282pt; line-height:12.5pt">\n    <span style="font-size:12.5pt">\n     Case\n    </span>\n    <span>\n     Nos.\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:0.2pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     (ANA\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:7.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     GLENN\n    </span>\n    <span style="font-size:12.5pt">\n     MORASH,\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:205.65pt; -aw-import:spaces">\n    </span>\n   </p>\n   <p style="margin-top:7.45pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:103.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:357pt; margin-bottom:0pt; text-align:justify; line-height:14.55pt">\n    <span style="font-size:12.5pt; font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-weight:bold">\n     AND\n    </span>\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:14pt; margin-bottom:0pt; text-align:justify; line-height:16.65pt">\n    <span style="font-size:10pt; font-weight:bold; letter-spacing:125.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:10pt; font-weight:bold">\n     VS.\n    </span>\n    <span style="font-weight:bold; letter-spacing:169.7pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     DISMISSING PETITION\n    </span>\n    <span>\n     FOR\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:389pt; margin-bottom:0pt; text-align:justify; line-height:14pt">\n    <span style="font-size:12.5pt">\n     REMOVAL\n    </span>\n  ...
# 2014_02_03_Price, Stephen.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 8
# done html
# done html
# 2014_02_03_Price, Stephen.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:538pt; height:292pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:54.95pt 103.75pt 0pt 16pt; text-indent:2pt; line-height:25.8pt">\n    <span style="height:0pt; margin-top:-54.95pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:121.6pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:2.6pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span>\n     BOARD\n    </span>\n    <span style="font-weight:bold; letter-spacing:190.8pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:8.45pt; margin-left:16pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:304pt; margin-bottom:0pt; text-align:justify; line-height:13.8pt">\n    <span>\n     Case No.\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:18pt">\n    <span style="font-weight:bold; letter-spacing:7.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STEPHEN\n    </span>\n    <span style="font-size:12.5pt">\n     PRICE,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:213.95pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     (Riverside District\n    </span>\n    <span>\n     Office)\n    </span>\n   </p>\n   <p style="margin-top:7.2pt; margin-left:15pt; margin-bottom:0pt; text-align:justify; line-height:15.75pt">\n    <span style="font-size:13pt; font-style:italic; letter-spacing:104pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin:6.4pt 26.9pt 0pt 14pt; text-indent:1pt; line-height:13.25pt">\n    <span style="font-size:13pt; letter-spacing:321.95pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     OPINION\n    </span>\n    <span style="font-size:12.5pt">\n     AND DECISION\n    </span>\n    <span style="font-size:11.5pt; letter-spacing:125.65pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt">\n     vs.\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:169.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     AFTER\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     AND\n    </span>\n    <span style="-aw-import:spaces">\n    </span>\n    <span>\n     ORDER\n    </span>\n    <span style="font-weight:bold">\n     RECONSIDERATIONIMPOSING\n    </span>\n   </p>\n   <p style="margin:1.05pt 37.05pt 0pt 14pt; text-indent:336pt; line-height:12pt">\n    <span style="font-weight:bold">\n     SANCTIONS\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     AND\n    </span>\n    <span style="letter-spacing:5.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WESTERN\n    </span>\n    <span style="font ...
# 2014_02_03_Ramirez, Jaime.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 3
# done html
# 2014_02_03_Ramirez, Jaime.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="height:0pt; display:block; position:absolute; z-index:-65539">\n     </span>\n     <span style="-aw-import:ignore">\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:27.25pt 111.3pt 0pt 30pt; text-indent:1pt; line-height:25pt">\n    <span style="height:0pt; margin-top:-27.25pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="letter-spacing:122.95pt; -aw-import:spaces">\n    </span>\n    <span>\n     WORKERS\'\n    </span>\n    <span style="font-weight:bold; letter-spacing:2.4pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     COMPENSATION\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:12.5pt">\n     BOARD\n    </span>\n    <span style="font-weight:bold; letter-spacing:191.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.6pt; margin-left:30pt; margin-bottom:7.3pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <div style="-aw-headerfooter-type:footer-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="font-weight:bold; color:#ff0000">\n     </span>\n    </p>\n   </div>\n  </div>\n  <br style="clear:both; mso-break-type:section-break"/>\n  <div>\n   <p style="margin-top:0.05pt; margin-left:14pt; margin-bottom:0pt; text-align:justify; line-height:12.5pt">\n   </p>\n   <p style="margin:0.5pt 124.1pt 0pt 14pt; text-indent:19pt; line-height:12pt">\n    <span style="font-weight:bold">\n     JAIME\n    </span>\n   </p>\n   <p style="margin:3.95pt 77.4pt 0pt 13pt; text-indent:118pt; line-height:12.5pt">\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:150pt; margin-bottom:0pt; text-align:justify; line-height:12.3pt">\n    <span style="font-size:11pt; font-weight:bold">\n     vs.\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:12.5pt">\n   </p>\n   <p style="margin-top:2.15pt; margin-left:32pt; margin-bottom:0pt; text-align:justify; line-height:14.05pt">\n    <span style="font-size:11.5pt; font-weight:bold">\n     GARDEN\n    </span>\n    <span>\n     GROVE\n    </span>\n    <span style="font-weight:bold">\n     CONVALESCENT\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:13pt; margin-bottom:0pt; text-align:justify; line-height:14.9pt">\n    <span style="font-weight:bold; letter-spacing:7.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     HOSPITAL; CALIFORNIA SELF-INSURED\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:12pt; margin-bottom:0pt; text-indent:20pt; line-height:12.65pt">\n    <span>\n     SECURITY\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     FUND,\n    </span>\n    <span style="font-size:12.5pt">\n     Administered\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:0.4pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     by\n    </span>\n    <span style="font-size:12.5pt">\n     METRO\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:7.45pt; -aw-import:spa ...
# 2014_02_03_Sanchez, Annie.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 5
# done html
# done html
# 2014_02_03_Sanchez, Annie.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:535pt; height:291pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:58.3pt; margin-left:6pt; margin-bottom:0pt; text-align:justify; line-height:17.75pt">\n    <span style="height:0pt; margin-top:-58.3pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:13pt; letter-spacing:122.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     WORKERS\'\n    </span>\n    <span style="font-size:12.5pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     COMPENSATION\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:12.5pt">\n     BOARD\n    </span>\n   </p>\n   <p style="margin-top:7.5pt; margin-left:4pt; margin-bottom:0pt; text-align:justify; line-height:16.65pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:192.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:12.5pt">\n     OF\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.8pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:0.05pt; margin-left:295pt; margin-bottom:0pt; text-align:justify; line-height:14.95pt">\n    <span style="font-size:12.5pt">\n     Case\n    </span>\n    <span>\n     No.\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:2.95pt; -aw-import:spaces">\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:15.75pt">\n    <span style="font-size:12.5pt; letter-spacing:6.8pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     ANNIE SANCHEZ,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:215.7pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     (Los Angeles\n    </span>\n    <span style="font-size:13pt">\n     District\n    </span>\n    <span style="font-size:12.5pt">\n     Office)\n    </span>\n   </p>\n   <p style="margin-top:9.15pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:21.45pt">\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:106.65pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:172.1pt">\n    </span>\n    <span style="font-size:12.5pt">\n     OPINION AND ORDER\n    </span>\n   </p>\n   <p style="margin-top:1.55pt; margin-left:5pt; margin-bottom:0pt; text-align:justify; line-height:16.05pt">\n    <span style="font-size:12.5pt; letter-spacing:319pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     GRANTING\n    </span>\n    <span style="font-size:13pt">\n     PETITION\n    </span>\n    <span style="font-size:12.5pt">\n     FOR\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:142pt; margin-bottom:0pt; text-align:justify; line-height:16pt">\n    <span style="font-size:12.5pt">\n     vs.\n    </span>\n    <span style="font-size:13pt; letter-spacing:177.75pt; -aw-import:spaces">\n   ...
# 2014_02_03_Thomas, Wanda.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 8
# done html
# done html
# ...
# 2014_02_04_Huezo, Jose.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 3
# done html
# 2014_02_04_Huezo, Jose.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:542pt; height:294pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:50.4pt 101.65pt 0pt 20pt; text-indent:2pt; line-height:26.25pt">\n    <span style="height:0pt; margin-top:-50.4pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:121.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     WORKERS\'\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     COMPENSATION APPEALS\n    </span>\n    <span style="font-size:13pt">\n     BOARD\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:190.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:13pt">\n     OF\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.05pt; margin-left:20pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:3.9pt; margin-left:19pt; margin-bottom:0pt; text-align:justify; line-height:19.05pt">\n    <span style="font-size:12.5pt; letter-spacing:277.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     Case\n    </span>\n    <span>\n     No.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:5pt; -aw-import:spaces">\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:37pt; margin-bottom:0pt; text-align:justify; line-height:21.75pt">\n    <span style="font-size:12.5pt; font-weight:bold">\n     JOSE HUEZO,\n    </span>\n    <span style="font-size:13pt; letter-spacing:239.15pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     (Marina\n    </span>\n    <span style="font-size:12.5pt">\n     del Rey District Office)\n    </span>\n   </p>\n   <p style="margin-top:7.55pt; margin-left:135pt; margin-bottom:0pt; text-align:justify; line-height:14.3pt">\n    <span style="font-size:13pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:18pt; margin-bottom:0pt; text-align:justify; line-height:20.5pt">\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:331.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:24.1pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:417pt; margin-bottom:0pt; text-align:justify; line-height:13.3pt">\n    <span style="font-weight:bold">\n     AND\n    </span>\n   </p>\n   <p style="margin:0.05pt 8.25pt 0pt 17pt; text-indent:137pt; line-height:13pt">\n    <span>\n     vs.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:156.25pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     GRANTING RECONSIDERATION\n    </span>\n    <span style="font-size:13pt; letter-spacing:357.95pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     DECISION\n    </span>\n   ...
# 2014_02_04_Kangas, Barbara.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 7
# done html
# done html
# 2014_02_04_Kangas, Barbara.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:534pt; height:290pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin-top:70.05pt; margin-left:8pt; margin-bottom:0pt; text-align:justify; line-height:14.8pt">\n    <span style="height:0pt; margin-top:-70.05pt; text-align:left; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:123.95pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     WORKERS\'\n    </span>\n    <span style="letter-spacing:1.8pt; -aw-import:spaces">\n    </span>\n    <span>\n     COMPENSATION\n    </span>\n    <span style="font-weight:bold; letter-spacing:0.8pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     APPEALS\n    </span>\n    <span>\n     BOARD\n    </span>\n   </p>\n   <p style="margin-top:10.15pt; margin-left:7pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n    <span style="font-weight:bold; letter-spacing:193.35pt; -aw-import:spaces">\n    </span>\n    <span style="font-weight:bold">\n     STATE\n    </span>\n    <span>\n     OF\n    </span>\n    <span style="font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:6.25pt; margin-left:8pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin:1.4pt 36.5pt 0pt 7pt; text-indent:293pt; line-height:12pt">\n    <span>\n     Case No.\n    </span>\n    <span>\n     (SRO\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:9.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     BARBARA KANGAS,\n    </span>\n   </p>\n   <p style="margin-top:14.35pt; margin-left:8pt; margin-bottom:0pt; text-align:justify; line-height:13.95pt">\n    <span style="font-size:12.5pt; font-style:italic; letter-spacing:104.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin:0.05pt 28.45pt 0pt 7pt; text-indent:337pt; line-height:12.5pt">\n    <span style="font-weight:bold">\n     OPINION\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     AND\n    </span>\n    <span style="font-weight:bold">\n     DECISION\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:315.45pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     AFTER\n    </span>\n    <span style="font-weight:bold">\n     RECONSIDERATION\n    </span>\n   </p>\n   <p style="margin-top:1.4pt; margin-left:144pt; margin-bottom:0pt; text-align:justify; line-height:9.05pt">\n    <span style="font-size:8pt; font-weight:bold">\n     VS.\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:7pt; margin-bottom:0pt; text-align:justify; line-height:13.25pt">\n   </p>\n   <p style="margin-top:12.3pt; margin-left:8pt; margin-bottom:0pt; text-align:justify; line-height:13.9pt">\n    <span style="letter-spacing:6pt; -aw-import:spaces">\n    </span>\n    <span>\n     REDBUD\n    </span>\n    <span style="font-weight:bold">\n     COMMUNITY HOSPITAL\n    </span>\n    <span>\n     and\n    </span>\n   </p>\n   <p style="margin:0.05pt 282.2pt 0pt 7pt; text-indent:19pt; line-height:12pt">\n    <span style="font-size:11.5pt; font-weight:bold">\n     ADVENTIST\n    </span>\n    <sp ...
# 2014_02_04_Marshall, Emmett.pdf
# [+] File: /content/ocr_txt_redo-0.pdf saved.
# 3
# done html
# 2014_02_04_Marshall, Emmett.pdf with contents {0: '<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="text/css" http-equiv="Content-Style-Type"/>\n  <title>\n  </title>\n </head>\n <body style="font-family:\'Times New Roman\'; font-size:12pt">\n  <div>\n   <div style="-aw-headerfooter-type:header-primary; clear:both">\n    <p style="margin-top:0pt; margin-bottom:0pt">\n     <span style="width:540pt; height:293pt; display:block">\n      <span style="height:0pt; display:block; position:absolute; z-index:-65538">\n      </span>\n     </span>\n    </p>\n   </div>\n   <p style="margin-top:0pt; margin-bottom:0pt">\n    <span style="font-weight:bold; color:#ff0000">\n    </span>\n   </p>\n   <p style="margin:54.7pt 101.3pt 0pt 18pt; text-indent:2pt; line-height:25.4pt">\n    <span style="height:0pt; margin-top:-54.7pt; display:block; position:absolute; z-index:0">\n    </span>\n    <span style="font-size:13pt; letter-spacing:122.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     WORKERS\'\n    </span>\n    <span style="font-size:12.5pt">\n     COMPENSATION\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     APPEALS\n    </span>\n    <span style="font-size:12.5pt">\n     BOARD\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:190.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     STATE\n    </span>\n    <span style="font-size:12.5pt">\n     OF\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     CALIFORNIA\n    </span>\n   </p>\n   <p style="margin-top:9.55pt; margin-left:18pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin-top:9.95pt; margin-left:17pt; margin-bottom:0pt; text-align:justify; line-height:14.35pt">\n   </p>\n   <p style="margin:0.85pt 29.9pt 0pt 17pt; line-height:17.3pt">\n    <span style="font-size:13pt; letter-spacing:6.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     EMMETT\n    </span>\n    <span style="font-size:12.5pt">\n     MARSHALL,\n    </span>\n    <span style="font-size:12.5pt; letter-spacing:127.85pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt">\n     Case No.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:2.55pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt">\n     (Long\n    </span>\n    <span style="font-size:12.5pt">\n     Beach\n    </span>\n    <span style="font-size:13pt">\n     District\n    </span>\n    <span style="font-size:12.5pt">\n     Office)\n    </span>\n    <span style="font-size:13pt; font-style:italic; letter-spacing:104.95pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:13pt; font-style:italic">\n     Applicant,\n    </span>\n   </p>\n   <p style="margin-top:1.3pt; margin-left:16pt; margin-bottom:0pt; text-align:justify; line-height:22.75pt">\n    <span style="font-size:11.5pt; font-weight:bold; letter-spacing:124.05pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:11.5pt; font-weight:bold">\n     vs.\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold; letter-spacing:173.9pt; -aw-import:spaces">\n    </span>\n    <span style="font-size:12.5pt; font-weight:bold">\n     GRANTING OPINION PETITION\n    </span>\n    <span style="font-weight:bold">\n     AND\n    </span>\n    <span style="font-size:12.5pt">\n     ORDER\n    </span>\n    <span style="font-size:13pt">\n     FOR\n    </span>\n   </p>\n   <p style="margin-top:0pt; margin-left:363pt; margin-bottom:0pt; text-align:justify; line-height:13.7pt">\n    <span style="font-size:12.5pt; font-weight:bold">\n     RECONSIDERATION\n    </span>\n   </p>\n   <p style="margin-top:0.05pt; margin-left:16pt; margin-bottom:0pt; text-align:justify; line-height:20.4pt">\n    <span style="font-size:13pt; letter-spacing:6.05pt; -aw-import:spaces">\n    ...
# 2014_02_04_Montgomery, Gregory.pdf
# [+] File: /content/ocr_txt_redo-1.pdf saved.
# 10
